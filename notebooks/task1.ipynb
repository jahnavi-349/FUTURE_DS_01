# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/SampleSuperstore.csv')
df.head()
# Out:
#    Order Date Region         Category Product Name  Sales
# 0  2023-01-01   East       Technology       Binder    619
# 1  2023-01-02  South  Office Supplies        Chair    249
# 2  2023-01-03   West  Office Supplies        Chair    576
# 3  2023-01-04   East  Office Supplies          Pen    492
# 4  2023-01-05  South       Technology          Pen    783

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order Date    200 non-null    str
#  1   Region        200 non-null    str
#  2   Category      200 non-null    str
#  3   Product Name  200 non-null    str
#  4   Sales         200 non-null    int64
# dtypes: int64(1), str(4)
# memory usage: 7.9 KB

# %%
df.isnull().sum()
# Out:
# Order Date      0
# Region          0
# Category        0
# Product Name    0
# Sales           0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

sales_trend = df.groupby(df['Order Date'].dt.month)['Sales'].sum()

sales_trend.plot(kind='line')
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.show()

# %%
top_products = df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(10)
top_products.plot(kind='bar')
plt.title("Top 10 Products by Sales")
plt.xlabel("Product")
plt.ylabel("Sales")
plt.xticks(rotation=45)
plt.show()

# %%
category_sales = df.groupby('Category')['Sales'].sum()

category_sales.plot(kind='pie', autopct='%1.1f%%')
plt.title("Category-wise Sales Distribution")
plt.ylabel("")  # removes extra label
plt.show()

# %%
region_sales = df.groupby('Region')['Sales'].sum()

region_sales.plot(kind='bar')
plt.title("Region-wise Sales Performance")
plt.xlabel("Region")
plt.ylabel("Sales")
plt.show()
